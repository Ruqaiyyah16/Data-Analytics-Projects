# %% [markdown]
# # 1. IMPORTING THE DATASET

# %%
dataset1 = read.csv("New_Covid19_Dataset.csv")

# %%
# EXPLORING THE DATASET

# %%
dataset1
# Out:
#     country                   continent         population total_tests_taken
# 1   Afghanistan               Asia               39869084    707244
# 2   Albania                   Europe              2874408    916777
# 3   Algeria                   Africa             44701619    230861
# 4   Andorra                   Europe                77398    193595
# 5   Angola                    Africa             33961015    681443
# 6   Anguilla                  North America         15147     31656
# 7   Antigua And Barbuda       North America         98802     17147
# 8   Argentina                 South America      45642150  19423553
# 9   Armenia                   Asia                2969212   1340258
# 10  Aruba                     North America        107254    177885
# 11  Australia                 Australia/Oceania  25818165  25012386
# 12  Austria                   Europe              9061746  66567305
# 13  Azerbaijan                Asia               10237543   4034340
# ...

# %% [markdown]
# # 3. DATA CLEANING

# %%
# FINDING THE MISSING VALUES

# %%
sapply(dataset1,function(x) sum(is.na(x)))
# Out:
#                        country                      continent
#                              0                              0
#                     population              total_tests_taken
#                              0                              0
#  total_tests_per_1m_population          total_cases_confirmed
#                              0                              0
#                   total_deaths                total_recovered
#                              0                              0
#                   active_cases               serious.critical
#                              0                              0
#  total_cases_per_1m_population total_deaths_per_1m_population
#                              0                              0

# %%
# REPLACING THE "NA" values

# %%
dataset1[is.na(dataset1)] = 0
dataset1
# Out:
#     country                   continent         population total_tests_taken
# 1   Afghanistan               Asia               39869084    707244
# 2   Albania                   Europe              2874408    916777
# 3   Algeria                   Africa             44701619    230861
# 4   Andorra                   Europe                77398    193595
# 5   Angola                    Africa             33961015    681443
# 6   Anguilla                  North America         15147     31656
# 7   Antigua And Barbuda       North America         98802     17147
# 8   Argentina                 South America      45642150  19423553
# 9   Armenia                   Asia                2969212   1340258
# 10  Aruba                     North America        107254    177885
# 11  Australia                 Australia/Oceania  25818165  25012386
# 12  Austria                   Europe              9061746  66567305
# 13  Azerbaijan                Asia               10237543   4034340
# ...

# %%
# checking for missing values

# %%
sapply(dataset1, function(x) sum(is.na(x)))
# Out:
#                        country                      continent
#                              0                              0
#                     population              total_tests_taken
#                              0                              0
#  total_tests_per_1m_population          total_cases_confirmed
#                              0                              0
#                   total_deaths                total_recovered
#                              0                              0
#                   active_cases               serious.critical
#                              0                              0
#  total_cases_per_1m_population total_deaths_per_1m_population
#                              0                              0

# %%
# checking for outliers using boxplot

plot = dataset1[,c("total_tests_taken","total_tests_per_1m_population","total_cases_confirmed",
                   "total_deaths","total_recovered","active_cases","serious.critical","total_cases_per_1m_population",
                   "total_deaths_per_1m_population")]
names(plot) = c("1","2","3","4","5","6","7","8","9")
boxplot(plot,xlab="PERCENTAGE",main="OUTLIERS")
# Out:
# Plot with title "OUTLIERS"

# %%
x = dataset1$total_cases_per_1m_population
y = dataset1$total_cases_per_1m_population
par(mfrow = c(1, 2))
format1 = paste("Total_cases_per_1m_population\n","with outliers")
format2 = paste("Total_cases_per_1m_population\n","without outliers")
boxplot(x, main=format1)
boxplot(y, main=format2,outline = FALSE)
# Out:
# Plot with title "Total_cases_per_1m_population
#  without outliers"

# %%
x = dataset1$total_deaths_per_1m_population
y = dataset1$total_deaths_per_1m_population
par(mfrow = c(1, 2))
format1 = paste("Total_deaths_per_1m_population\n","with outliers")
format2 = paste("Total_deaths_per_1m_population\n","without outliers")
boxplot(x, main=format1)
boxplot(y, main=format2,outline = FALSE)
# Out:
# Plot with title "Total_deaths_per_1m_population
#  without outliers"

# %% [markdown]
# # 2. DATA EXPLORATION

# %%
str(dataset1)
# Out:
# 'data.frame':	220 obs. of  12 variables:
#  $ country                       : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ continent                     : chr  "Asia" "Europe" "Africa" "Europe" ...
#  $ population                    : int  39869084 2874408 44701619 77398 33961015 15147 98802 45642150 2969212 107254 ...
#  $ total_tests_taken             : num  707244 916777 230861 193595 681443 ...
#  $ total_tests_per_1m_population : num  17739 318945 5164 2501292 20065 ...
#  $ total_cases_confirmed         : int  147473 133081 171392 14678 42646 113 1303 4929764 230110 11730 ...
#  $ total_deaths                  : num  6736 2457 4254 128 1008 ...
#  $ total_recovered               : num  98073 130222 115276 14210 36708 ...
#  $ active_cases                  : num  42664 402 51862 340 4930 ...
#  $ serious.critical              : num  1124 3 47 0 8 ...
#  $ total_cases_per_1m_population : int  3699 46299 3834 189643 1256 7460 13188 108009 77499 109367 ...
# ...

# %%
summary(dataset1)
# Out:
#    country           continent           population        total_tests_taken
#  Length:220         Length:220         Min.   :8.030e+02   Min.   :        0
#  Class :character   Class :character   1st Qu.:6.347e+05   1st Qu.:   151498
#  Mode  :character   Mode  :character   Median :6.581e+06   Median :  1080210
#                                        Mean   :3.564e+07   Mean   : 13669747
#                                        3rd Qu.:2.418e+07   3rd Qu.:  6375370
#                                        Max.   :1.439e+09   Max.   :529577328
#  total_tests_per_1m_population total_cases_confirmed  total_deaths
#  Min.   :       0              Min.   :       1      Min.   :     0.0
#  1st Qu.:   64166              1st Qu.:    7896      1st Qu.:   110.8
#  Median :  318208              Median :   77338      Median :  1054.0
#  Mean   :  861561              Mean   :  902192      Mean   : 19235.8
#  3rd Qu.:  967685              3rd Qu.:  409994      3rd Qu.:  6884.5
# ...

# %%
dim(dataset1)
# Out:
# [1] 220  12

# %%
head(dataset1,5)
# Out:
#   country     continent population total_tests_taken
# 1 Afghanistan Asia      39869084   707244
# 2 Albania     Europe     2874408   916777
# 3 Algeria     Africa    44701619   230861
# 4 Andorra     Europe       77398   193595
# 5 Angola      Africa    33961015   681443
#   total_tests_per_1m_population total_cases_confirmed total_deaths
# 1   17739                       147473                6736
# 2  318945                       133081                2457
# 3    5164                       171392                4254
# 4 2501292                        14678                 128
# 5   20065                        42646                1008
#   total_recovered active_cases serious.critical total_cases_per_1m_population
# 1  98073          42664        1124               3699
# 2 130222            402           3              46299
# 3 115276          51862          47               3834
# 4  14210            340           0             189643
# ...

# %%
tail(dataset1,5)
# Out:
#     country                   continent         population total_tests_taken
# 216 Wallis And Futuna Islands Australia/Oceania    11026     20508
# 217 Western Sahara            Africa              613090         0
# 218 Yemen                     Asia              30530919    152937
# 219 Zambia                    Africa            18935680   2089592
# 220 Zimbabwe                  Africa            15095525   1088771
#     total_tests_per_1m_population total_cases_confirmed total_deaths
# 216 1859967                          445                   7
# 217       0                           10                   1
# 218    5009                         7061                1375
# 219  110352                       195816                3389
# 220   72125                       107490                3490
#     total_recovered active_cases serious.critical total_cases_per_1m_population
# 216    438              0          0              40359
# ...

# %%
names(dataset1)
# Out:
#  [1] "country"                        "continent"
#  [3] "population"                     "total_tests_taken"
#  [5] "total_tests_per_1m_population"  "total_cases_confirmed"
#  [7] "total_deaths"                   "total_recovered"
#  [9] "active_cases"                   "serious.critical"
# [11] "total_cases_per_1m_population"  "total_deaths_per_1m_population"

# %% [markdown]
# # 4. DATA VISUALISATION

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.1.1"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
total.cases.confirmed = dataset1 %>% arrange(desc(total_cases_confirmed))
total.cases.confirmed
# Out:
#     country                          continent         population
# 1   USA                              North America      333093143
# 2   India                            Asia              1394605426
# 3   Brazil                           South America      214186368
# 4   Russia                           Europe             146001924
# 5   France                           Europe              65429176
# 6   UK                               Europe              68270129
# 7   Turkey                           Asia                85315528
# 8   Argentina                        South America       45642150
# 9   Colombia                         South America       51466439
# 10  Spain                            Europe              46774302
# 11  Italy                            Europe              60365948
# 12  Iran                             Asia                85149163
# 13  Germany                          Europe              84072622
# ...

# %%
top_total_confirmed_cases = head(total.cases.confirmed,10)
top_total_confirmed_cases
# Out:
#    country   continent     population total_tests_taken
# 1  USA       North America  333093143 529577328
# 2  India     Asia          1394605426 466427038
# 3  Brazil    South America  214186368  55034721
# 4  Russia    Europe         146001924 165300000
# 5  France    Europe          65429176 104611244
# 6  UK        Europe          68270129 244114700
# 7  Turkey    Asia            85315528  67868851
# 8  Argentina South America   45642150  19423553
# 9  Colombia  South America   51466439  22533319
# 10 Spain     Europe          46774302  55855941
#    total_tests_per_1m_population total_cases_confirmed total_deaths
# 1  1589878                       35733967              629290
# 2   334451                       31654584              424384
# 3   256948                       19917855              556370
# 4  1132177                        6265873              158563
# 5  1598847                        6127019              111867
# ...

# %%
slices = (top_total_confirmed_cases $total_cases_confirmed)
total = dataset1$total_cases_confirmed
pct = round(slices/sum(total)*100,digit = 1)
labels = paste(top_total_confirmed_cases$country," ",pct,"%",sep="")
title = paste("PIE CHART OF TOP 10 COUNTRIES WITH","\n","HIGHEST NUMBER OF CONFIRMED CASES")


pie(slices,labels = labels,col = c("#FFB5E8","#FFC8A2","#ACE7FF","#FFBEBC","#AFF8DB","#C5A3FF",
                                   "#fb6f92","#FFFFD1","#C1DBDD","#55CBCD"),main = title)

legend(0.9,0.9, top_total_confirmed_cases$country, cex = 0.8,fill = c("#FFB5E8","#FFC8A2","#ACE7FF",
                                        "#FFBEBC","#AFF8DB","#C5A3FF","#fb6f92","#FFFFD1","#C1DBDD","#55CBCD"))
# Out:
# Plot with title "PIE CHART OF TOP 10 COUNTRIES WITH
#  HIGHEST NUMBER OF CONFIRMED CASES"

# %%
library(ggplot2)
ggplot(dataset1, aes(x = continent, y = total_recovered)) + geom_point(aes(color = continent),size = 2.2)+
ggtitle("RECOVERED CASES IN EACH CONTINENT") +
  labs(x="Continent", y="Total recovered") + theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
asia_continent = filter(dataset1,continent == "Asia")
asia_continent
# Out:
#    country              continent population total_tests_taken
# 1  Afghanistan          Asia        39869084    707244
# 2  Armenia              Asia         2969212   1340258
# 3  Azerbaijan           Asia        10237543   4034340
# 4  Bahrain              Asia         1764852   5447238
# 5  Bangladesh           Asia       166455064   7740894
# 6  Bhutan               Asia          780749    798573
# 7  Brunei Darussalam    Asia          441987    152986
# 8  Cambodia             Asia        16967753   1809439
# 9  China Hong Kong Sar  Asia         7562460  21390075
# 10 China Macao Sar      Asia          658853      4671
# 11 China                Asia      1439323776 160000000
# 12 Cyprus               Asia         1216822   9366973
# 13 Georgia              Asia         3980909   6781466
# 14 India                Asia      1394605426 466427038
# 15 Indonesia            Asia       276635762  26301202
# 16 Iran                 Asia        85149163  25857430
# ...

# %%
count(asia_continent)
# Out:
#   n
# 1 49

# %%
recovered.cases = asia_continent %>% arrange(desc(total_recovered))
recovered.cases
# Out:
#    country              continent population total_tests_taken
# 1  India                Asia      1394605426 466427038
# 2  Turkey               Asia        85315528  67868851
# 3  Iran                 Asia        85149163  25857430
# 4  Indonesia            Asia       276635762  26301202
# 5  Philippines          Asia       111149482  16682875
# 6  Iraq                 Asia        41191025  13076929
# 7  Bangladesh           Asia       166455064   7740894
# 8  Pakistan             Asia       225498161  15995153
# 9  Malaysia             Asia        32811983  18160251
# 10 Israel               Asia         9326000  16462447
# 11 Japan                Asia       126058811  18382964
# 12 Jordan               Asia        10312137   8493724
# 13 United Arab Emirates Asia        10018939  65922553
# 14 Nepal                Asia        29699747   3603465
# 15 Lebanon              Asia         6792467   4731376
# 16 Saudi Arabia         Asia        35396603  25029275
# ...

# %%
top_recovered_cases = head(recovered.cases,10)
top_recovered_cases
# Out:
#    country     continent population total_tests_taken
# 1  India       Asia      1394605426 466427038
# 2  Turkey      Asia        85315528  67868851
# 3  Iran        Asia        85149163  25857430
# 4  Indonesia   Asia       276635762  26301202
# 5  Philippines Asia       111149482  16682875
# 6  Iraq        Asia        41191025  13076929
# 7  Bangladesh  Asia       166455064   7740894
# 8  Pakistan    Asia       225498161  15995153
# 9  Malaysia    Asia        32811983  18160251
# 10 Israel      Asia         9326000  16462447
#    total_tests_per_1m_population total_cases_confirmed total_deaths
# 1   334451                       31654584              424384
# 2   795504                        5727045               51332
# 3   303672                        3871008               90630
# 4    95075                        3409658               94119
# 5   150094                        1588965               27889
# 6   317470                        1626599               18657
# ...

# %%
library(ggplot2)
ggplot(data=top_recovered_cases , aes(x=country, y=total_recovered,group = 1)) +geom_line(color="yellow", size=1) +  
  geom_point(color="orange",size=2.5) + ggtitle("RECOVERED CASES IN ASIA") +  
  labs(x="Country", y="Recovered Cases") + theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
library(dplyr)  # for cleaning

# %%
highest_arrange_death = dataset1 %>% arrange(desc(total_deaths))
highest_arrange_death
# Out:
#     country                          continent         population
# 1   USA                              North America      333093143
# 2   Brazil                           South America      214186368
# 3   India                            Asia              1394605426
# 4   Mexico                           North America      130390343
# 5   Peru                             South America       33465698
# 6   Russia                           Europe             146001924
# 7   UK                               Europe              68270129
# 8   Italy                            Europe              60365948
# 9   Colombia                         South America       51466439
# 10  France                           Europe              65429176
# 11  Argentina                        South America       45642150
# 12  Indonesia                        Asia               276635762
# 13  Germany                          Europe              84072622
# ...

# %%
top_cases = head(highest_arrange_death,10)
top_cases
# Out:
#    country  continent     population total_tests_taken
# 1  USA      North America  333093143 529577328
# 2  Brazil   South America  214186368  55034721
# 3  India    Asia          1394605426 466427038
# 4  Mexico   North America  130390343   8421353
# 5  Peru     South America   33465698  15476472
# 6  Russia   Europe         146001924 165300000
# 7  UK       Europe          68270129 244114700
# 8  Italy    Europe          60365948  77544194
# 9  Colombia South America   51466439  22533319
# 10 France   Europe          65429176 104611244
#    total_tests_per_1m_population total_cases_confirmed total_deaths
# 1  1589878                       35733967              629290
# 2   256948                       19917855              556370
# 3   334451                       31654584              424384
# 4    64586                        2829443              240456
# 5   462458                        2109294              196291
# ...

# %%
library(ggplot2)
ggplot(data = top_cases, aes(x=country, y=total_deaths)) + 
geom_bar(stat = "identity",fill = c("#FFB5E8","#FFC8A2","#ACE7FF","#FFBEBC","#AFF8DB","#C5A3FF","#fb6f92",
                                    "#FFFFD1","#C1DBDD","#55CBCD"))+
ggtitle("TOP TEN COUNTRIES BASED ON THE COUNT OF DEATH CASE")+
  theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
library(corrplot)
# Out:
# Warning message:
# "package 'corrplot' was built under R version 4.1.1"
# corrplot 0.90 loaded

# %%
data<-data.frame(dataset1$population,dataset1$total_tests_taken,dataset1$total_tests_per_1m_population,dataset1$total_cases_confirmed,dataset1$total_deaths,dataset1$total_recovered,dataset1$active_cases,dataset1$serious.critical,dataset1$total_cases_per_1m_population,dataset1$total_deaths_per_1m_population)
mydata<-write.csv("Corrplot-R.csv")
mydata<- as.matrix(data)

cor(mydata)
# Out:
# "","x"
# "1","Corrplot-R.csv"
#                                         dataset1.population
# dataset1.population                      1.00000000
# dataset1.total_tests_taken               0.64836263
# dataset1.total_tests_per_1m_population  -0.07539193
# dataset1.total_cases_confirmed           0.54669896
# dataset1.total_deaths                    0.44939323
# dataset1.total_recovered                 0.57003803
# dataset1.active_cases                    0.22448602
# dataset1.serious.critical                0.45052081
# dataset1.total_cases_per_1m_population  -0.08845945
# dataset1.total_deaths_per_1m_population -0.03544798
#                                         dataset1.total_tests_taken
# dataset1.population                     0.6483626
# dataset1.total_tests_taken              1.0000000
# dataset1.total_tests_per_1m_population  0.1379404
# dataset1.total_cases_confirmed          0.8896559
# dataset1.total_deaths                   0.7659657
# ...

# %%
corrplot(cor(mydata), method="number")
# Out:
# Plot with title ""

# %% [markdown]
# # 5. MACHINE LEARNING ALGORITHM

# %% [markdown]
# LINEAR REGRESSION

# %%
library(caTools)

# %% [markdown]
# total_cases_confirmed

# %%
cor(dataset1$total_cases_confirmed,dataset1$total_deaths)
# Out:
# [1] 0.9340761

# %%
data1 = dataset1
creating_sample1 = sample.split(data1,SplitRatio = 0.7)
training_set1 = subset(data1,split = TRUE)
testing_set1 = subset(data1,split = FALSE)
model1 = lm(data1$total_deaths~data1$total_cases_confirmed,data = data1)
model1
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$total_cases_confirmed,
#     data = data1)
#
# Coefficients:
#                 (Intercept)  data1$total_cases_confirmed
#                   2.948e+03                    1.805e-02

# %%
predicting1 = predict(model1,testing_set1)
print(predicting1)
# Out:
#          1          2          3          4          5          6          7
#   5610.605   5350.781   6042.423   3213.211   3718.127   2950.264   2971.748
#          8          9         10         11         12         13         14
#  91946.945   7102.479   3159.990   3564.385  14846.388   9155.848   3216.136
#         15         16         17         18         19         20         21
#   7807.931  25505.588   3027.478  11000.737  23253.090   3203.914   3099.764
#         22         23         24         25         26         27         28
#   2994.314   2993.628  11484.079   6660.984   4874.335 362532.096   2993.358
#         29         30         31         32         33         34         35
#   2954.308  10618.584   3193.262   3076.042   3558.265   4342.719   4429.754
#         36         37         38         39         40         41         42
#  28779.399   2979.041   2959.832   3077.324   3038.003   3114.459  32118.292
# ...

# %%
accuracy1 = sqrt(mean((testing_set1$total_deaths-predicting1)^2))
accuracy1
# Out:
# [1] 24777.77

# %%
summary(model1)
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$total_cases_confirmed,
#     data = data1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -150035   -3534   -2961   -2684  193838
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 2.948e+03  1.730e+03   1.704   0.0898 .
# data1$total_cases_confirmed 1.805e-02  4.674e-04  38.624   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 24890 on 218 degrees of freedom
# Multiple R-squared:  0.8725,	Adjusted R-squared:  0.8719
# F-statistic:  1492 on 1 and 218 DF,  p-value: < 2.2e-16

# %% [markdown]
# serious.critical

# %%
cor(dataset1$serious.critical,dataset1$total_deaths)
# Out:
# [1] 0.8399891

# %%
creating_sample2 = sample.split(data1,SplitRatio = 0.7)
training_set2 = subset(data1,split = TRUE)
testing_set2 = subset(data1,split = FALSE)
model2 = lm(data1$total_deaths~data1$serious.critical,data = data1)
model2
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$serious.critical, data = data1)
#
# Coefficients:
#            (Intercept)  data1$serious.critical
#                1980.23                   43.18

# %%
predicting2 = predict(model2,testing_set2)
print(predicting2)
# Out:
#          1          2          3          4          5          6          7
#  50513.640   2109.770   4009.654   1980.233   2325.666   1980.233   2109.770
#          8          9         10         11         12         13         14
# 173660.684   1980.233   2584.741   4527.805   3361.967   1980.233   2455.204
#         15         16         17         18         19         20         21
#   2152.949  60228.957   1980.233   1980.233   5995.897   2066.591   2196.128
#         22         23         24         25         26         27         28
#   1980.233   1980.233  10616.070   1980.233   2023.412 361144.718   3146.071
#         29         30         31         32         33         34         35
#   1980.233   5218.672   1980.233   1980.233   2973.354   1980.233   8543.469
#         36         37         38         39         40         41         42
#  11954.625   1980.233   1980.233   2066.591   1980.233   1980.233  62215.200
# ...

# %%
accuracy2 = sqrt(mean((testing_set2$total_deaths-predicting2)^2))
accuracy2
# Out:
# [1] 37651.86

# %%
summary(model2)
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$serious.critical, data = data1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -233384   -2249   -1930     262  222505
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            1980.233   2659.505   0.745    0.457
# data1$serious.critical   43.179      1.889  22.857   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 37820 on 218 degrees of freedom
# Multiple R-squared:  0.7056,	Adjusted R-squared:  0.7042
# F-statistic: 522.4 on 1 and 218 DF,  p-value: < 2.2e-16

# %% [markdown]
# active_cases

# %%
cor(dataset1$active_cases,dataset1$total_deaths)
# Out:
# [1] 0.7400396

# %%
creating_sample3 = sample.split(data1,SplitRatio = 0.7)
training_set3 = subset(data1,split = TRUE)
testing_set3 = subset(data1,split = FALSE)
model3 = lm(data1$total_deaths~data1$active_cases,data = data1)
model3
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$active_cases, data = data1)
#
# Coefficients:
#        (Intercept)  data1$active_cases
#          1.026e+04           1.333e-01

# %%
predicting3 = predict(model3,testing_set3)
print(predicting3)
# Out:
#         1         2         3         4         5         6         7         8
#  15945.82  10311.15  17172.16  10302.89  10914.86  10257.82  10260.89  44188.09
#         9        10        11        12        13        14        15        16
#  11008.46  10318.89  10694.87  10963.12  11044.19  10517.15  10391.68  30334.88
#        17        18        19        20        21        22        23        24
#  10272.62  10575.68  15777.56  10311.69  10277.56  10260.89  10276.09  16648.59
#        25        26        27        28        29        30        31        32
#  11137.38  11563.90 109178.63  10331.55  10264.76  11340.84  10262.22  11097.25
#        33        34        35        36        37        38        39        40
#  10321.82  11037.52  10297.16  11135.65  10261.42  10258.89  10283.42  10258.49
#        41        42        43        44        45        46        47        48
#  10599.41  11568.30  10265.56  10258.22  10387.02  21734.08  10259.69  10335.82
# ...

# %%
accuracy3 = sqrt(mean((testing_set3$population-predicting3)^2))
accuracy3
# Out:
# [1] 144354315

# %%
summary(model3)
# Out:
# Call:
# lm(formula = data1$total_deaths ~ data1$active_cases, data = data1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -106079  -10262  -10096   -6998  447191
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        1.026e+04  3.209e+03   3.197   0.0016 **
# data1$active_cases 1.333e-01  8.207e-03  16.246   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 46880 on 218 degrees of freedom
# Multiple R-squared:  0.5477,	Adjusted R-squared:  0.5456
# F-statistic: 263.9 on 1 and 218 DF,  p-value: < 2.2e-16

# %% [markdown]
# # conclusion
#
# total_cases_confirmed - 87 %
# active_cases      - 54 %
# serious_critical      - 70 %
